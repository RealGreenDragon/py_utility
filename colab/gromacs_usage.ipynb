# %% [markdown]
# #Template to use pre-builded GROMACS installation

# %%
# Set up Python environment
# !pip install --upgrade pip setuptools cmake scikit-build

# Download and unzip the compressed folder of GROMACS 2021.5 version
# !wget [LINK]
# !tar xzf gromacs-2021.5.tar.gz

# %%
# %%bash
# # Load GROMACS environment
# source /content/gromacs-2021.5/bin/GMXRC
#
# # Install gmxapi Python modules
# !pip install --upgrade gmxapi
#
# # Checking that GROMACS works
# gmx -h
